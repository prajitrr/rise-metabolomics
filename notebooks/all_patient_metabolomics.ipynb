# %%
import pandas as pd
import numpy as np

# %%
quant_table = pd.read_csv("../data/metabolomics_data/mzmine_output_full_feature_table.csv", nrows=1)
# Get list of column names
quant_table_columns = quant_table.columns.tolist()
# Select the "id" column and any column containing ":area" in the name
quant_columns = [col for col in quant_table_columns if ":area" in col]
# Create a new DataFrame with the selected columns
filtered_quant_table = pd.read_csv("../data/metabolomics_data/mzmine_output_full_feature_table.csv", usecols=["id"] + quant_columns)
# Remove the first row

# %%
filtered_quant_table
# Out:
#           id  datafile:P2_A10_364173029.mzML:area  \
# 0         51                                871.6
# 1         54                                109.6
# 2         57                               9443.0
# 3         68                               4044.0
# 4         75                               1826.0
# ...      ...                                  ...
# 32138  96273                                862.9
# 32139  96274                               2824.0
# 32140  96276                               2083.0
# 32141  96288                                343.8
# 32142  96298                                811.6
#
#        datafile:P2_A11_Rise_PlateBlank_1.mzML:area  \
# 0                                           4923.0
# 1                                            184.4
# 2                                          14240.0
# 3                                           3475.0
# 4                                           4200.0
# ...
